# %% [markdown]
# # 解答

# %%
class Solution:
    def searchMatrix(self, matrix: list[list[int]], target: int) -> bool:
        m = len(matrix); n = len(matrix[0])
        exist = False

        for i in range(m):
            if target in matrix[i]:
                exist = True
                break

        return exist

# %% [markdown]
# # 官方

# %% [markdown]
# 方法一：直接查找

# %%
class Solution:
    def searchMatrix(self, matrix: list[list[int]], target: int) -> bool:
        for row in matrix:
            for element in row:
                if element == target:
                    return True
        return False

# %% [markdown]
# 方法二：二分查找

# %%
import bisect

class Solution:
    def searchMatrix(self, matrix: list[list[int]], target: int) -> bool:
        for row in matrix:
            idx = bisect.bisect_left(row, target)
            if idx < len(row) and row[idx] == target:
                return True
        return False

# %% [markdown]
# 方法三：Z 字形查找

# %%
class Solution:
    def searchMatrix(self, matrix: list[list[int]], target: int) -> bool:
        m, n = len(matrix), len(matrix[0])
        x, y = 0, n - 1
        while x < m and y >= 0:
            if matrix[x][y] == target:
                return True
            if matrix[x][y] > target:
                y -= 1
            else:
                x += 1
        return False

# %% [markdown]
# # 测试

# %%
solution = Solution()
matrix = [[1,4,7,11,15],[2,5,8,12,19],[3,6,9,16,22],[10,13,14,17,24],[18,21,23,26,30]]
target_1 = 5; target_2 = 20
print(solution.searchMatrix(matrix, target_1), solution.searchMatrix(matrix, target_2))
# Out:
# True False
